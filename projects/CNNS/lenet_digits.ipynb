# %% [markdown]
# ## 1. Importing Libraries

# %%
import os
from re import T
import sys
import numpy as np
from pathlib import Path
from rich.console import Console
from rich.panel import Panel
from rich.table import Table
from rich.live import Live
from rich.text import Text
from rich import box
import pickle
# Ensure project root is in path
project_root = r"C:\Users\HP 840 G3\OneDrive\Desktop\NanoTorch\projects\CNNS\lenet_digits.ipynb"  
sys.path.insert(0, project_root)

import nanotorch as nt
import nanotorch.nn as nn
from nanotorch.utils.data import DataLoader, TensorDataset
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[6], line 17
#      13 # Ensure project root is in path
#      14 project_root = r"C:\Users\HP 840 G3\OneDrive\Desktop\NanoTorch\projects\CNNS\lenet_digits.ipynb"
#      15 sys.path.insert(0, project_root)
#      16
# ---> 17 import nanotorch as nt
#      18 import nanotorch.nn as nn
#      19 from nanotorch.utils.data import DataLoader, TensorDataset
#
# ModuleNotFoundError: No module named 'nanotorch'
